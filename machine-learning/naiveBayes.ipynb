# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import CategoricalNB

df = pd.read_csv('./../data/Naive_Bayes_Lab_Dataset.csv')
df.head()
# Out:
#   Student Study_Hours Previous_Grade Outcome
# 0       A        High           Good    Pass
# 1       B         Low           Poor    Fail
# 2       C      Medium           Good    Pass
# 3       D      Medium           Poor    Fail
# 4       E        High           Good    Pass

# %%
study_map = {'Low':0, 'Medium':1, 'High':2}
grade_map = {'Poor':0,'Good':1}
outcome_map = {'Fail':0,"Pass":1}

df['Study_Hours_enc'] = df['Study_Hours'].map(study_map)
df['Previous_Grade_enc'] = df["Previous_Grade"].map(grade_map)
df['Outcome_enc'] = df['Outcome'].map(outcome_map)

# %%
X = df[['Study_Hours_enc', 'Previous_Grade_enc']]
y = df['Outcome_enc']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=2)

model = CategoricalNB()
model.fit(X_train, y_train)
# Out:
# CategoricalNB()

# %%
test_input = pd.DataFrame([[1,0]],columns=['Study_Hours_enc', 'Previous_Grade_enc'])
prediction = model.predict(test_input)
print("Prediction:",'Pass' if prediction[0] == 1 else 'Fail')
# Out:
# Prediction: Fail
