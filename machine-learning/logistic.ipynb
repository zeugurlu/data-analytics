# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error, ConfusionMatrixDisplay
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("../data/disease_synthetic.csv")
df
# Out:
#      Unnamed: 0        Age        BMI  Exercise_Frequency  Disease_Outcome
# 0             0  70.000000  17.775299            8.443270                1
# 1             1  51.002358  18.947285            3.154652                1
# 2             2  59.681070  21.056654            5.995813                1
# 3             3  70.000000  30.473192            4.301809                1
# 4             4  70.000000  26.174108            9.090928                1
# ..          ...        ...        ...                 ...              ...
# 695         695  61.361246  20.255336            0.544982                1
# 696         696  39.806258  25.659559            1.912022                1
# 697         697  33.080455  15.097172            6.040269                1
# 698         698  47.969509  28.843853            6.621837                1
# 699         699  61.229028  22.893362            5.809958                1
#
# [700 rows x 5 columns]

# %%
depen
