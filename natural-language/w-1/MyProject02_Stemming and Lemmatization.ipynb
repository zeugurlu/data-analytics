# %% [markdown]
# # Import nltk and Porter Stemmer

# %%
import nltk
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()

# %%
words = ['charging', 'charges', 'charged', 'charge', 'study', 'studying','easily','fairly', 'losses', 'was', 'necessary', 'implementation','permission', 'learn']

# %%
for word in words:
  print(word, ": ", ps.stem(word))
# Out:
# charging :  charg
# charges :  charg
# charged :  charg
# charge :  charg
# study :  studi
# studying :  studi
# easily :  easili
# fairly :  fairli
# losses :  loss
# was :  wa
# necessary :  necessari
# implementation :  implement
# permission :  permiss
# learn :  learn

# %%
sentence = "Police is chasing the suspect as it ran away".split()
# Since porter.stem needs one word at a time, therefore we used split()

# %%
for token in sentence:
  print(ps.stem(token))
# Out:
# polic
# is
# chase
# the
# suspect
# as
# it
# ran
# away

# %% [markdown]
# # Snowball Stemmer

# %%
from nltk.stem.snowball import SnowballStemmer

snow_stemmer = SnowballStemmer(language='english') # Need to pass a language parameter

# %%
for word in words:
  print(word, ": ", snow_stemmer.stem(word))
# Out:
# charging :  charg
# charges :  charg
# charged :  charg
# charge :  charg
# study :  studi
# studying :  studi
# easily :  easili
# fairly :  fair
# losses :  loss
# was :  was
# necessary :  necessari
# implementation :  implement
# permission :  permiss
# learn :  learn

# %%
for token in sentence:
  print(snow_stemmer.stem(token))
# Out:
# polic
# is
# chase
# the
# suspect
# as
# it
# ran
# away

# %% [markdown]
# # Lemmatization with Spacy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp("Police is chasing the suspect as it ran away")

# %%
for token in doc:
  print(token.text, " : ", token.lemma_)
# Out:
# Police  :  Police
# is  :  be
# chasing  :  chase
# the  :  the
# suspect  :  suspect
# as  :  as
# it  :  it
# ran  :  run
# away  :  away

# %%
doc1 = nlp("I saw 10 mice")

# %%
for token in doc1:
  print(token.text, " : ", token.lemma_)
# Out:
# I  :  I
# saw  :  see
# 10  :  10
# mice  :  mouse

# %%
doc2 = nlp("He will be meeting me on Friday at the meeting")

# %%
for token in doc2:
  print(token.text, " : ", token.lemma_) # spacy differentiate between verb and noun
# Out:
# He  :  he
# will  :  will
# be  :  be
# meeting  :  meet
# me  :  I
# on  :  on
# Friday  :  Friday
# at  :  at
# the  :  the
# meeting  :  meeting

# %% [markdown]
# # Lemmatization with nltk

# %%
from nltk.stem import WordNetLemmatizer

# %%
nltk.download("wordnet") # wordnet is a database in NLTK Library
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import wordnet # import wordnet

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("studying")
# Out:
# 'studying'

# %%
lemmatizer.lemmatize("studying", pos=wordnet.VERB)
# Out:
# 'study'

# %% [markdown]
# # Function for mapping the treebank tags to WordNet part of speech names

# %%
# Reference : https://stackoverflow.com/questions/15586721/wordnet-lemmatization-and-pos-tagging-in-python

def get_wordnet_pos(treebank_tag):

    if treebank_tag.startswith('J'):
        return wordnet.ADJ
    elif treebank_tag.startswith('V'):
        return wordnet.VERB
    elif treebank_tag.startswith('N'):
        return wordnet.NOUN
    elif treebank_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
sentence = "Police is chasing the suspect as it ran away".split()

# %%
words_and_tags = nltk.pos_tag(sentence)
words_and_tags
# Out:
# [('Police', 'NNP'),
#  ('is', 'VBZ'),
#  ('chasing', 'VBG'),
#  ('the', 'DT'),
#  ('suspect', 'NN'),
#  ('as', 'IN'),
#  ('it', 'PRP'),
#  ('ran', 'VBD'),
#  ('away', 'RB')]

# %%
for word, tag in words_and_tags:
  lemma = lemmatizer.lemmatize(word, pos=get_wordnet_pos(tag))
  print(lemma, end=" ")
# Out:
# Police be chase the suspect a it run away

# %%
# For detail about the Treebank tag set visit https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html

# %%
sentence2 = "He will be meeting me on Friday at the meeting".split()

# %%
words_and_tags = nltk.pos_tag(sentence2)
words_and_tags
# Out:
# [('He', 'PRP'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('meeting', 'VBG'),
#  ('me', 'PRP'),
#  ('on', 'IN'),
#  ('Friday', 'NNP'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('meeting', 'NN')]

# %%
for word, tag in words_and_tags:
  lemma = lemmatizer.lemmatize(word, pos=get_wordnet_pos(tag))
  print(lemma, end=" ")
# Out:
# Police be chase the suspect a it run away

# %% [markdown]
# # Comparing Stemming and Lemmatization

# %%
words = ['charging', 'charges', 'charged', 'charge', 'study', 'studying','easily','fairly', 'losses', 'was', 'necessary', 'implementation','permission', 'learn', 'learning', 'learned', 'learns', 'mice']

# %%
words_and_tags = nltk.pos_tag(words)

# %%
for word, tag in words_and_tags:
  lemma = lemmatizer.lemmatize(word, pos=get_wordnet_pos(tag))
  print(lemma,   "       :       ", ps.stem(word))
# Out:
# charge        :        charg
# charge        :        charg
# charge        :        charg
# charge        :        charg
# study        :        studi
# study        :        studi
# easily        :        easili
# fairly        :        fairli
# loss        :        loss
# be        :        wa
# necessary        :        necessari
# implementation        :        implement
# permission        :        permiss
# learn        :        learn
# learn        :        learn
# learn        :        learn
# learns        :        learn
# mouse        :        mice
